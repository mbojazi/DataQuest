# %% [markdown]
# # Exploring Job Outcomes

# %% [markdown]
# ## Import Libraries and Employ Jupyter Magic to Display Plots Inline

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Open, Read, and Display First Row of DataFrame

# %%
recent_grads = pd.read_csv("recent-grads.csv",encoding="Latin-1")

recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %% [markdown]
# ## Display First Five Rows of DataFrame

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %% [markdown]
# ## Display Last Five Rows of DataFrame

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %% [markdown]
# ## Examine Statistics of All Numeric Columns of Data

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %% [markdown]
# ## Extract Number of Rows from DataFrame and Drop Any Rows with Missing Data

# %%
raw_data_count = recent_grads.shape[0]

recent_grads = recent_grads.dropna()

# %% [markdown]
# ## Extract New Number of Rows from DataFrame and Compare to Previous Number (Only 1 Row with Missing Data)

# %%
cleaned_data_count = recent_grads.shape[0]

print(raw_data_count)
print(cleaned_data_count)
# Out:
# 173
# 172

# %% [markdown]
# ## Generate Scatter Plots Exploring Various Relations

# %%
recent_grads.plot(x='Sample_size', y='Employed', kind='scatter', title='Employed vs. Sample_size', xlim=(-200,4500), ylim=(-20000,350000))

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter', title='Median vs. Sample_size', xlim=(-200,4500), ylim=(-10000,120000))

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', title='Unemployment_rate vs. Sample_size', xlim=(-200,4500), ylim=(-0.015,0.2))

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter', title='Median vs. Full_time', xlim=(-12000,275000), ylim=(-10000,120000))

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', title='Unemployment_rate vs. ShareWomen', xlim=(-0.05,1.05), ylim=(-0.02,0.2))

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter', title='Median vs. Men', xlim=(-10000,200000), ylim=(-10000,120000))

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter', title='Median vs. Women', xlim=(-15000,325000), ylim=(-10000,120000))

# %% [markdown]
# ## In Particular, Do Students in More Popular Majors Make More Money?  The Following Scatter Plots Shed Light on the Question.

# %%
recent_grads.plot(x='Total', y='Low_wage_jobs', kind='scatter', title='Low_wage_jobs vs. Total', xlim=(-20000,425000), ylim=(-5000,55000))

# %%
recent_grads.plot(x='Total', y='Median', kind='scatter', title='Median vs. Total', xlim=(-20000,425000), ylim=(-10000,120000))

# %% [markdown]
# From the plot of Low_wage_jobs vs. Total, we see that, in general, as the total number of people with a certain major (or, major popularity) increases, so does the number of people in low-wage service jobs post graduation.  There is a strong, positive correlation of major popularity with students in such majors ending up in low-wage service jobs.  These increasing numbers of students in low-wage services jobs post graduation with increasing major popularity result in the downward trend of median earnings as said popularity increases in the plot of Median vs. Total.  It appears, then, that students in more popular majors make less money.

# %% [markdown]
# ## Do Students that Majored in Subjects that were Majority Female Make More Money?  The Following Scatter Plot Sheds Light on the Question.

# %%
recent_grads.plot(x='ShareWomen', y='Median', kind='scatter', title='Median vs. ShareWomen', xlim=(-0.05,1.05), ylim=(-10000,120000))

# %% [markdown]
# From the above plot, there is a clear downward trend in the median earnings as the percentage of women with a particular major increases.  It appears, then, students majoring in subjects increasingly dominated by a female population make less money.

# %% [markdown]
# ## Generate Histograms Exploring Various Relations

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,4500))

# %%
recent_grads['Median'].hist(bins=25, range=(0,120000))

# %%
recent_grads['Employed'].hist(bins=25, range=(0,325000))

# %%
recent_grads['Full_time'].hist(bins=25, range=(0,275000))

# %%
recent_grads['ShareWomen'].hist(bins=25, range=(0,1.2))

# %%
recent_grads['Unemployment_rate'].hist(bins=25, range=(0,0.20))

# %%
recent_grads['Men'].hist(bins=25, range=(0,200000))

# %%
recent_grads['Women'].hist(bins=25, range=(0,350000))

# %% [markdown]
# ## Generate Scatter Matrix Plots Exploring Various Relations

# %%
from pandas.tools.plotting import scatter_matrix

scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(8,8))
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2d11b215f8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2d119464e0>]], dtype=object)

# %% [markdown]
# ## Generate Bar Plots Exploring Various Relations

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')
recent_grads.tail(10).plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')
recent_grads.tail(10).plot.bar(x='Major', y='Unemployment_rate')
